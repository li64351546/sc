# %%
list(adata.obs[CELL_TYPE_KEY].unique())

# %%
adata.obs[CELL_TYPE_KEY].value_counts()

# %%
import sys;sys.path.append('../')

# %%
# !pip uninstall -y numpy anndata treedata
# !pip install numpy==1.26.4 anndata==0.10.7 treedata==0.1.0 -i https://pypi.tuna.tsinghua.edu.cn/simple
# !pip install -U xarray

# %%
import scanpy as sc
sc.logging.print_versions()

# %%
sc.logging.print_header()

# %%
pip install numpy==1.23.5 scanpy==1.9.3 anndata==0.8.0 pandas==1.5.3 -i https://pypi.tuna.tsinghua.edu.cn/simple --force-reinstall

pip install numpy==1.23.5 scanpy==1.9.3 anndata==0.8.0 pandas==1.5.3 cvxpy==1.4.2 -i https://pypi.tuna.tsinghua.edu.cn/simple --force-reinstall
